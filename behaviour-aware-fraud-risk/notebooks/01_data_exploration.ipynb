# %% [markdown]
# # 01 — Data exploration (Person 1 / 2)
#
# Load `data/raw/transactions.csv` after Person 1 generates it.
# Until then: `python -m src.make_dummy_features`

# %%
from pathlib import Path
import pandas as pd

raw = Path("../data/raw/transactions.csv")
if raw.exists():
    df = pd.read_csv(raw, parse_dates=["timestamp"])
    display(df.head())
    print(df["is_fraud"].value_counts(normalize=True))
else:
    print("No raw file yet.")
